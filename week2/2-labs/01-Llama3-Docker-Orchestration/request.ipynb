# %% [markdown]
# <div style="background-color:#b5add6; padding: 1em; color: black;">
#     DAH - Week2, Lab1
# </div>

# %% [markdown]
# * Import dependencies

# %%
import requests

# %% [markdown]
# * Utils

# %%
url = 'http://127.0.0.1:11434/api/generate'
reviews = [
    "1 - Les horaires d'ouverture des agences ne sont pas pratiques pour les travailleurs. Les taux d'intérêt sont très compétitifs. Le processus de clôture de compte est très compliqué.",
    "2 - L'ouverture de compte a été très rapide et simple. Le personnel est toujours accueillant et souriant.",
    "3 - Je suis déçu par le manque de transparence sur les frais. La banque offre de nombreux services utiles pour les PME.",
    "4 - Les notifications par SMS sont très utiles pour suivre les transactions. C'est quoi cette merde vous avez de longue fille devant votre agence. J'attend pendant 3h et on me dire que je ne peut etre servir. Je ne reviendrai plus jamais.",
    "5 - Je trouve que les applications bancaires sont trop compliquées. Le service de conseil en investissement est excellent. Les horaires d'ouverture des agences ne sont pas pratiques pour les travailleurs."
]
prompt_params = {
    "model": "llama3",
    "prompt": "Extract and return list of topics from these reviews also extract sentiement per topic and give the result in this format {topic:sentiment}: " + str(reviews),
    "stream": False
}

# %% [markdown]
# * Chating with LLAMA3

# %%
response = requests.post(url, json=prompt_params)

if response.status_code == 200:
    response_data = response.json()
    api_response = response_data.get('response', 'No response field found')
    print("Response: ")
    print(api_response)
else:
    print(f"Failed to retrieve data, status code {response.status_code}")
# Out:
# Response:
# After analyzing the reviews, I extracted the following topics:
#
# 1. **Opening Hours**: {Topic: Sentiment} = {"Opening Hours": -0.5}
# 	* Reviews 1 and 5 mention inconvenient opening hours for workers.
# 2. **Interest Rates**: {Topic: Sentiment} = {"Interest Rates": 0.7}
# 	* Review 1 mentions competitive interest rates.
# 3. **Account Opening Process**: {Topic: Sentiment} = {"Account Opening Process": 0.4}
# 	* Reviews 1, 3, and 4 mention the process of opening an account, with mixed sentiments (complicated vs. simple).
# 4. **Bank Services for SMEs**: {Topic: Sentiment} = {"Bank Services for SMEs": 0.5}
# 	* Review 3 mentions that the bank offers useful services for small and medium-sized enterprises (SMEs).
# 5. **Customer Service**: {Topic: Sentiment} = {"Customer Service": -1.0}
# 	* Reviews 4 and 5 express dissatisfaction with customer service (long wait times, lack of transparency).
# 6. **Mobile Banking App**: {Topic: Sentiment} = {"Mobile Banking App": -0.2}
# 	* Review 5 mentions that the mobile banking app is too complicated.
# 7. **Transparency on Fees**: {Topic: Sentiment} = {"Transparency on Fees": -0.8}
# 	* Review 4 expresses frustration with a lack of transparency on fees.
#
# Please note that sentiment scores are based on my analysis and might not reflect the exact sentiment expressed in each review, as they can be subjective.
